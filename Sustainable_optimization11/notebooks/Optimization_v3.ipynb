# %%
# Imports
import numpy as np
import pandas as pd
import pulp

from warnings import filterwarnings
filterwarnings("ignore")


vehicles_df = pd.read_csv('../data/Master_data/vehicle_master_data.csv')
distances_df = pd.read_csv('../data/Master_data/distance_master_data.csv')

# %%
input_df = pd.read_csv("../data/Input_data/Input2.csv")
vehicles_df
# input_df
# Out:
#    Transportation modes        Vehicle_type  Capacity (metric tons)  \
# 0                   Air         CARGO PLANE                     100
# 1                  Rail          GOODS RAIL                    8000
# 2                  Rail          MIXED RAIL                    5000
# 3                  Road  HGV DROPSIDE LORRY                      24
# 4                  Road         4WD PICK UP                      18
# 5                  Road                 VAN                      12
# 6                  Road            PICK  UP                      10
# 7                  Road         HGV (Large)                      36
# 8                  Road     CAR DERIVED VAN                       2
# 9                  Road            ELECTRIC                       7
# 10                 Road              TIPPER                      11
# 11                 Road        TIPPER (HGV)                       3
# 12                 Road           PANEL VAN                       9
# 13                 Road              ESTATE                       1
# 14                 Road         HGV (Small)                      15
# 15                 Road           LARGE VAN                       8
# 16                 Road       MOTOR CARAVAN                      13
# 17                 Road          HGV LOADER                       4
# 18                 Road                 4x4                       2
#
#     Co2e (g/km)  Avg Speed (km/hr)  Cost per km  \
# 0    551.584454                500        10.00
# 1     97.565914                 50         4.00
# 2    107.090591                 90         5.50
# 3    156.598994                 45         1.30
# 4    155.605476                 42         1.20
# 5    211.365144                 70         1.40
# 6    209.320194                 55         1.34
# 7    155.398594                 34         1.23
# 8    187.850299                 65         1.41
# 9    151.765792                 58         1.52
# 10    88.180958                 40         1.36
# 11   264.030218                 30         1.32
# 12   157.257768                 60         1.38
# 13   104.260522                 80         1.50
# 14   190.411547                 52         1.43
# 15   145.588808                 60         1.44
# 16   125.195841                 50         1.47
# 17   186.902781                 28         1.37
# 18   159.151851                 58         1.42
#
#     Minimum Quantity Allowed (MQA)
# 0                             90.0
# 1                           4000.0
# 2                           2000.0
# 3                             10.0
# 4                             10.0
# 5                              5.0
# 6                              3.0
# 7                             20.0
# 8                              0.5
# 9                              2.0
# 10                             2.0
# 11                             1.0
# 12                             2.0
# 13                             0.1
# 14                             3.0
# 15                             2.0
# 16                             5.0
# 17                             1.0
# 18                             0.5

# %%
input_df
# Out:
#         From         To  Quantity (MT)  Time (hrs)    Cost
# 0      Delhi     Mumbai           3000        30.0   50000
# 1      Delhi    Kolkata          24000        44.5   30450
# 2      Delhi    Chennai             13        48.0   15600
# 3  Bangalore     Mumbai            100         2.0  144000
# 4  Bangalore    Kolkata          13130        53.2  190320
# 5  Bangalore    Chennai             14        50.0   40049
# 6    Chennai      Delhi           1752        55.6  140000
# 7    Chennai    Kolkata           8450        44.0   28500
# 8    Chennai     Mumbai             15        57.0  660000
# 9    Chennai  Bangalore          35618        54.0  175000

# %%
# Create a dictionary 'vehicles' containing information about vehicles categorized by their 'Transportation modes'
vehicles = {}
for mode in vehicles_df['Transportation modes']:
    # Create a list to store information about vehicles for the current mode
    vehicles_list = []
    
    # Iterate over the rows that belong to the current 'Transportation mode' in the 'vehicles_df' DataFrame
    for j in range(len(vehicles_df[vehicles_df['Transportation modes'] == mode])):
        # Create a dictionary 'vehicle_info' for each row of 'vehicles_df' belonging to the current mode 'mode'
        vehicle_info = {}
        
        # Iterate over the columns (except for 'Transportation modes') and store the information in 'vehicle_info'
        for column in vehicles_df[vehicles_df['Transportation modes'] == mode].columns[1:]:
            vehicle_info[column] = vehicles_df[column][j]
        
        # Add the 'vehicle_info' dictionary to the 'vehicles_list' for the current mode
        vehicles_list.append(vehicle_info)
    
    # Add the list of vehicles for the current mode 'mode' to the 'vehicles' dictionary with the mode as the key
    vehicles[mode] = vehicles_list

# Create a dictionary 'distances' containing information about distances between 'Source' and 'Destination'
distances = {}
for j in range(len(distances_df)):
    # Create a dictionary 'distance_info' for each row of 'distances_df' for the current source and destination
    distance_info = {}
    
    # Iterate over the columns (starting from the third column) and store the distance information in 'distance_info'
    for column in distances_df.columns[2:]:
        distance_info[column] = distances_df[column][j]
    
    # Add the 'distance_info' dictionary to the 'distances' dictionary with the source and destination as the key
    distances[(distances_df['Source'][j], distances_df['Destination'][j])] = distance_info

# Perform a cross join between 'distances_df' and 'vehicles_df' to create a new DataFrame 'df'
df = distances_df.join(vehicles_df, how="cross")

# Create a new column 'decisions' in 'df' containing a string concatenation of various columns
df['decisions'] = df['Source'] + ', ' + df['Destination'] + ', ' + df['Transportation modes'] + ', ' + df['Vehicle_type']

# %%
df
# Out:
#       Source Destination  Air Distance (km)  Rail Distance (km)  \
# 0     Mumbai     Kolkata            1655.79             1723.03
# 1     Mumbai     Kolkata            1655.79             1723.03
# 2     Mumbai     Kolkata            1655.79             1723.03
# 3     Mumbai     Kolkata            1655.79             1723.03
# 4     Mumbai     Kolkata            1655.79             1723.03
# ..       ...         ...                ...                 ...
# 375  Chennai   Bangalore             290.95              303.61
# 376  Chennai   Bangalore             290.95              303.61
# 377  Chennai   Bangalore             290.95              303.61
# 378  Chennai   Bangalore             290.95              303.61
# 379  Chennai   Bangalore             290.95              303.61
#
#      Road Distance (km) Transportation modes        Vehicle_type  \
# 0               2071.24                  Air         CARGO PLANE
# 1               2071.24                 Rail          GOODS RAIL
# 2               2071.24                 Rail          MIXED RAIL
# 3               2071.24                 Road  HGV DROPSIDE LORRY
# 4               2071.24                 Road         4WD PICK UP
# ..                  ...                  ...                 ...
# 375              365.20                 Road         HGV (Small)
# 376              365.20                 Road           LARGE VAN
# 377              365.20                 Road       MOTOR CARAVAN
# 378              365.20                 Road          HGV LOADER
# 379              365.20                 Road                 4x4
#
#      Capacity (metric tons)  Co2e (g/km)  Avg Speed (km/hr)  Cost per km  \
# 0                       100   551.584454                500        10.00
# 1                      8000    97.565914                 50         4.00
# 2                      5000   107.090591                 90         5.50
# 3                        24   156.598994                 45         1.30
# 4                        18   155.605476                 42         1.20
# ..                      ...          ...                ...          ...
# 375                      15   190.411547                 52         1.43
# 376                       8   145.588808                 60         1.44
# 377                      13   125.195841                 50         1.47
# 378                       4   186.902781                 28         1.37
# 379                       2   159.151851                 58         1.42
#
#      Minimum Quantity Allowed (MQA)                                  decisions
# 0                              90.0          Mumbai, Kolkata, Air, CARGO PLANE
# 1                            4000.0          Mumbai, Kolkata, Rail, GOODS RAIL
# 2                            2000.0          Mumbai, Kolkata, Rail, MIXED RAIL
# 3                              10.0  Mumbai, Kolkata, Road, HGV DROPSIDE LORRY
# 4                              10.0         Mumbai, Kolkata, Road, 4WD PICK UP
# ..                              ...                                        ...
# 375                             3.0      Chennai, Bangalore, Road, HGV (Small)
# 376                             2.0        Chennai, Bangalore, Road, LARGE VAN
# 377                             5.0    Chennai, Bangalore, Road, MOTOR CARAVAN
# 378                             1.0       Chennai, Bangalore, Road, HGV LOADER
# 379                             0.5              Chennai, Bangalore, Road, 4x4
#
# [380 rows x 13 columns]

# %%
# Create a dictionary 'master_availability' to store the initial availability of different vehicle types
# The initial availability for all vehicle types is set to 10
master_availability = dict(zip(df['Vehicle_type'].unique(), [5] * len(df['Vehicle_type'].unique())))
master_availability["HGV (Large)"]=3
# Create a dictionary 'master_demand' to store the initial demand for vehicles between different sources and destinations
# The initial demand for all unique source-destination combinations is set to 0
master_demand = {}

# Get the unique combinations of 'Source' and 'Destination' from the DataFrame 'df'
unique_source_destination = np.array(df[['Source', 'Destination']].drop_duplicates())

# Iterate over the unique combinations of 'Source' and 'Destination'
for source_dest in unique_source_destination:
    # Use the combination as a key in the 'master_demand' dictionary and set the initial demand to 0
    master_demand[tuple(source_dest)] = 0


master_availability
# Out:
# {'CARGO PLANE': 1,
#  'GOODS RAIL': 1,
#  'MIXED RAIL': 1,
#  'HGV DROPSIDE LORRY': 1,
#  '4WD PICK UP': 1,
#  'VAN': 1,
#  'PICK  UP': 1,
#  'HGV (Large)': 3,
#  'CAR DERIVED VAN': 1,
#  'ELECTRIC': 1,
#  'TIPPER': 1,
#  'TIPPER (HGV)': 1,
#  'PANEL VAN': 1,
#  'ESTATE': 1,
#  'HGV (Small)': 1,
#  'LARGE VAN': 1,
#  'MOTOR CARAVAN': 1,
#  'HGV LOADER': 1,
#  '4x4': 1}

# %%
# Create a dictionary 'demand' to store the demand for vehicles between different "From" and "To" locations
demand = {}

# Extract the unique combinations of "From" and "To" locations from the DataFrame 'input_df'
unique_source_destination = np.array(input_df[['From', 'To']])

# Extract the corresponding demand values (quantity in metric tons) from the DataFrame 'input_df'
demand_values = input_df['Quantity (MT)']

# Pair each unique combination of "From" and "To" locations with the corresponding demand value
for source_dest, demand_value in zip(unique_source_destination, demand_values):
    # Use the combination as a key in the 'demand' dictionary and set the demand value as the value
    demand[tuple(source_dest)] = demand_value

# Iterate over the keys of the 'master_demand' dictionary to check for missing keys in 'demand'
for key in master_demand.keys():
    # If the key does not exist in 'demand', set its value to 0 (indicating no demand)
    if key not in demand:
        demand[key] = 0


demand
# Out:
# {('Delhi', 'Mumbai'): 3000,
#  ('Delhi', 'Kolkata'): 24000,
#  ('Delhi', 'Chennai'): 13,
#  ('Bangalore', 'Mumbai'): 100,
#  ('Bangalore', 'Kolkata'): 13130,
#  ('Bangalore', 'Chennai'): 14,
#  ('Chennai', 'Delhi'): 1752,
#  ('Chennai', 'Kolkata'): 8450,
#  ('Chennai', 'Mumbai'): 15,
#  ('Chennai', 'Bangalore'): 35618,
#  ('Mumbai', 'Kolkata'): 0,
#  ('Mumbai', 'Delhi'): 0,
#  ('Mumbai', 'Bangalore'): 0,
#  ('Mumbai', 'Chennai'): 0,
#  ('Kolkata', 'Mumbai'): 0,
#  ('Kolkata', 'Delhi'): 0,
#  ('Kolkata', 'Bangalore'): 0,
#  ('Kolkata', 'Chennai'): 0,
#  ('Delhi', 'Bangalore'): 0,
#  ('Bangalore', 'Delhi'): 0}

# %%
# %%time

##########################################################
#------------------- Model Definition -------------------#
##########################################################
# Create a LP minimization problem
model = pulp.LpProblem("Co2e Optimization", pulp.LpMinimize)
            
############################################################
#------------------- Decision Variables -------------------#
############################################################

# Create a dictionary to store both binary decision variables with prefixes "Choice_Decision_" and "Return_Count_"
choice_decision = pulp.LpVariable.dicts("Choice_Decision_", 
                                        (tuple(df['decisions'][i].split(", ")) + (j,) 
                                          for i in range(len(df)) 
                                          for j in range(master_availability[df['decisions'][i].split(", ")[-1]]) ),
                                        lowBound=0, cat="Binary")

# Add the "Return_Count_" decision variables with the same format
return_count_decision = pulp.LpVariable.dicts("Return_Count_", 
                                              (tuple(df['decisions'][i].split(", ")) + (j,) 
                                                for i in range(len(df)) 
                                                for j in range(master_availability[df['decisions'][i].split(", ")[-1]]) ),
                                              lowBound=0, cat="Integer")


############################################################
#------------------- Objective Function -------------------#
############################################################

# Create an empty list to store the contributions to the objective function
obj_tup = []

# Iterate through each combination of decision variables
for (s, d, m, v, c) in choice_decision.keys():
    # Retrieve the binary decision variable for the current combination
    decision_var = choice_decision[(s, d, m, v, c)]
    return_count_key = tuple([s, d, m, v, c])
    decision_return_var = return_count_decision[return_count_key]

    # Retrieve the distance and CO2 emissions for the current combination from the DataFrame 'df'
    distance_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                     (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)][m + ' Distance (km)'].item()
    # print(distance_km)
    co2_emissions_g_per_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                                (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)]['Co2e (g/km)'].item()

    # print(decision_var,decision_return_var)

    # Calculate the contribution to the objective function for the current combination and add it to 'obj_tup'
    contribution = 2*decision_var * distance_km * (co2_emissions_g_per_km / 1000)
    
    contribution1 = 2*decision_return_var * distance_km * (co2_emissions_g_per_km / 1000)
    # print(contribution)
    obj_tup.append(contribution)
    obj_tup.append(contribution1)

# Sum up all the contributions to form the objective function and add it to the optimization model
model += pulp.lpSum(obj_tup)

# obj_tup

# #####################################################
# #------------------- Constraints -------------------#
# #####################################################

# #========== Demand Constraint ==========
(s0, d0, m0, v0, c0) = list(choice_decision.keys())[0]
col = []

for (s, d, m, v, c) in choice_decision.keys():

    if(s0, d0) == (s, d):
        col.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
        col.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
    else:
        if demand[(s0, d0)] == 0:
            model += (pulp.lpSum(col)==demand[(s0, d0)])
            (s0, d0) = (s, d)
            col=[]
            col.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
            col.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
        elif demand[(s0, d0)] >= 0:
            model += (pulp.lpSum(col)>=demand[(s0, d0)])
            (s0, d0) = (s, d)
            col=[]
            col.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
            col.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())

if demand[(s0, d0)] >= 0:
    model += (pulp.lpSum(col)>=demand[(s0, d0)])
elif demand[(s0, d0)] >= 0:
    model += (pulp.lpSum(col)>=demand[(s0, d0)])

# #========== Minimum Quantity Allowed Constraint ==========
(s0, d0, m0, v0, c0) = list(choice_decision.keys())[0]
col1 = []

for (s, d, m, v, c) in choice_decision.keys():

    if(s0, d0) == (s, d):
        col1.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())
        col1.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())
    else:
        if demand[(s0, d0)] == 0:
            model += (pulp.lpSum(col1)<=demand[(s0, d0)])
            (s0, d0) = (s, d)
            col1=[]
            col1.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())
            col1.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())
        if demand[(s0, d0)] >= 0:
            model += (pulp.lpSum(col1)<=demand[(s0, d0)])
            (s0, d0) = (s, d)
            col1=[]
            col1.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())
            col1.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Minimum Quantity Allowed (MQA)'].item())

if demand[(s0, d0)] >= 0:
    model += (pulp.lpSum(col1)<=demand[(s0, d0)])
if demand[(s0, d0)] >= 0:
    model += (pulp.lpSum(col1)<=demand[(s0, d0)])


#========== Cost Constraint ==========
(s0, d0, m0, v0, c0) = list(choice_decision.keys())[0]
col = []

for (s, d, m, v, c) in choice_decision.keys():
    if((s0, d0) == (s, d)) & input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
        col.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)][m+' Distance (km)'].item()*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Cost per km'].item())
        col.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)][m+' Distance (km)'].item()*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Cost per km'].item())
    elif (s0, d0) != (s, d):
        if input_df[(input_df['From']==s0) & (input_df['To']==d0)].shape[0]:
            model += (pulp.lpSum(col)<=input_df[(input_df['From']==s0) & (input_df['To']==d0)]['Cost'])
            (s0, d0) = (s, d)
            col=[]
            col.append(choice_decision[(s, d, m, v, c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
            col.append(return_count_decision[(s,d,m,v,c)]*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Capacity (metric tons)'].item())
        else:
            (s0, d0) = (s, d)
            col=[]

if input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
    model += (pulp.lpSum(col)<=input_df[(input_df['From']==s0) & (input_df['To']==d0)]['Cost'])


#========== Other Constraint ==========

for (s, d, m, v, c) in choice_decision.keys():
    return_var= return_count_decision[(s,d,m,v,c)]
    choice_var= choice_decision[(s,d,m,v,c)]
    model += return_var <= 10000000*choice_var




for (s, d, m, v, c) in choice_decision.keys():
    if m != "Road":
        return_var= return_count_decision[(s,d,m,v,c)]
    
        model += return_var ==0

#========== Time Constraint ==========
for (s, d, m, v, c) in choice_decision.keys():
    if input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
        exp1 = df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)][m+' Distance (km)'].item()/df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Avg Speed (km/hr)'].item()
        exp= (choice_decision[(s, d, m, v, c)]*exp1)+(return_count_decision[(s,d,m,v,c)]*2.5*exp1)
        # print(exp,"eeeee")
        model += pulp.LpConstraint(e=pulp.LpAffineExpression(exp), sense=pulp.LpConstraintLE, rhs = input_df[(input_df['From']==s) & (input_df['To']==d)]['Time (hrs)'].item())






    






# return_count_decision
# Out:
# CPU times: total: 7.23 s
# Wall time: 7.27 s

# %%
# %%time
###############################################
#------------------- Solve -------------------#
###############################################

model.solve()
print(pulp.LpStatus[model.status])
# Out:
# Infeasible
# CPU times: total: 62.5 ms
# Wall time: 161 ms

# %%
# optimal_combinations = []
# for v in model.variables():
#     if v.varValue > 0:  # Consider non-zero values to get the selected combinations
#         optimal_combinations.append((v.name, v.varValue))

# # Sort the combinations based on CO2 emissions (assuming 'CO2e' is the CO2 emissions variable name)
# # optimal_combinations.sort(key=lambda x: float(x[0].split('_')[-1]), reverse=False)

# # Print the combinations in ascending order of CO2 emissions
# for combination, count in optimal_combinations:
#     print(f"Combination: {combination}, Count: {count}, CO2 Emissions: {(combination.split('_')[-1])}")

# %%
model.variables
# Out:
# <bound method LpProblem.variables of Co2e_Optimization:
# MINIMIZE
# 320.96699366622*Choice_Decision__('Bangalore',_'Chennai',_'Air',_'CARGO_PLANE',_0) + 59.243974493390404*Choice_Decision__('Bangalore',_'Chennai',_'Rail',_'GOODS_RAIL',_0) + 65.027548727742*Choice_Decision__('Bangalore',_'Chennai',_'Rail',_'MIXED_RAIL',_0) + 113.65423967040002*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'4WD_PICK_UP',_0) + 116.24451211648*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'4x4',_0) + 137.2058583896*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0) + 110.84973462287999*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'ELECTRIC',_0) + 76.15188556096*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'ESTATE',_0) + 113.5031326924*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_(Large)',_0) + 113.5031326924*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_(Large)',_1) + 113.5031326924*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_(Large)',_2) + 139.07659422095998*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_(Small)',_0) + 114.37990507151997*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0) + 136.51379102328*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_LOADER',_0) + 106.33806550927997*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'LARGE_VAN',_0) + 91.44304212031999*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0) + 114.86107382024*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'PANEL_VAN',_0) + 152.88746962455997*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'PICK__UP',_0) + 64.407371913104*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'TIPPER',_0) + 192.84767100807997*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'TIPPER_(HGV)',_0) + 154.38110146975998*Choice_Decision__('Bangalore',_'Chennai',_'Road',_'VAN',_0) + 1912.1998893666118*Choice_Decision__('Bangalore',_'Delhi',_'Air',_'CARGO_PLANE',_0) + 351.9612306362544*Choice_Decision__('Bangalore',_'Delhi',_'Rail',_'GOODS_RAIL',_0) + 386.32074014596196*Choice_Decision__('Bangalore',_'Delhi',_'Rail',_'MIXED_RAIL',_0) + 674.77381034544*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'4WD_PICK_UP',_0) + 690.1524536177279*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'4x4',_0) + 814.60155059556*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0) + 658.1232519277679*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'ELECTRIC',_0) + 452.11949975625595*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'ESTATE',_0) + 673.87667679714*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_0) + 673.87667679714*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_1) + 673.87667679714*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_2) + 825.7082506072559*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Small)',_0) + 679.0821406740719*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0) + 810.4926943387079*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_LOADER',_0) + 631.3371314308079*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'LARGE_VAN',_0) + 542.9042518787519*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0) + 681.938875899564*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'PANEL_VAN',_0) + 907.7044616357158*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'PICK__UP',_0) + 382.39143463699435*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'TIPPER',_0) + 1144.9511972429877*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'TIPPER_(HGV)',_0) + 916.5722667819358*Choice_Decision__('Bangalore',_'Delhi',_'Road',_'VAN',_0) + 1719.255647427372*Choice_Decision__('Bangalore',_'Kolkata',_'Air',_'CARGO_PLANE',_0) + 316.4667510066384*Choice_Decision__('Bangalore',_'Kolkata',_'Rail',_'GOODS_RAIL',_0) + 347.36118310378197*Choice_Decision__('Bangalore',_'Kolkata',_'Rail',_'MIXED_RAIL',_0) + 606.7337599096801*Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'4WD_PICK_UP',_0) + 620.561715162016*Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'4x4' ...
# SUBJECT TO
# _C1: 100 Choice_Decision__('Mumbai',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Mumbai',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Mumbai',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Mumbai',_'Kolkata',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Mumbai',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Mumbai',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Mumbai',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Mumbai',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Mumbai',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Mumbai',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Mumbai',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Mumbai',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Mumbai',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Mumbai',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Mumbai',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Mumbai',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Mumbai',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Mumbai',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Mumbai',_'Kolkata',_'Road',_'VAN',_0) = 0
#
# _C2: 100 Choice_Decision__('Mumbai',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Mumbai',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Mumbai',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Mumbai',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Mumbai',_'Delhi',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Mumbai',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Mumbai',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Mumbai',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Mumbai',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Mumbai',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Mumbai',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Mumbai',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Mumbai',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Mumbai',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Mumbai',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Mumbai',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Mumbai',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Mumbai',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Mumbai',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Mumbai',_'Delhi',_'Road',_'VAN',_0) = 0
#
# _C3: 100 Choice_Decision__('Mumbai',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Mumbai',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Mumbai',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Mumbai',_'Bangalore',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Mumbai',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Mumbai',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Mumbai',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Mumbai',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Mumbai',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Mumbai',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Mumbai',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Mumbai',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Mumbai',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Mumbai',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Mumbai',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Mumbai',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Mumbai',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Mumbai',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Mumbai',_'Bangalore',_'Road',_'VAN',_0) = 0
#
# _C4: 100 Choice_Decision__('Mumbai',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Mumbai',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Mumbai',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Mumbai',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Mumbai',_'Chennai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Mumbai',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Mumbai',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Mumbai',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Mumbai',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Mumbai',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Mumbai',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Mumbai',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Mumbai',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Mumbai',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Mumbai',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Mumbai',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Mumbai',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Mumbai',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Mumbai',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Mumbai',_'Chennai',_'Road',_'VAN',_0) = 0
#
# _C5: 100 Choice_Decision__('Kolkata',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Kolkata',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Kolkata',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Kolkata',_'Mumbai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Kolkata',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Kolkata',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Kolkata',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Kolkata',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Kolkata',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Kolkata',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Kolkata',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Kolkata',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Kolkata',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Kolkata',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Kolkata',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Kolkata',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Kolkata',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Kolkata',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Kolkata',_'Mumbai',_'Road',_'VAN',_0) = 0
#
# _C6: 100 Choice_Decision__('Kolkata',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Kolkata',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Kolkata',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Kolkata',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Kolkata',_'Delhi',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Kolkata',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Kolkata',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Kolkata',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Kolkata',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Kolkata',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Kolkata',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Kolkata',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Kolkata',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Kolkata',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Kolkata',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Kolkata',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Kolkata',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Kolkata',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Kolkata',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Kolkata',_'Delhi',_'Road',_'VAN',_0) = 0
#
# _C7: 100 Choice_Decision__('Kolkata',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Kolkata',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Kolkata',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Kolkata',_'Bangalore',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Kolkata',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Kolkata',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Kolkata',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Kolkata',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Kolkata',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Kolkata',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Kolkata',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Kolkata',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Kolkata',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Kolkata',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Kolkata',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Kolkata',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Kolkata',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Kolkata',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Kolkata',_'Bangalore',_'Road',_'VAN',_0) = 0
#
# _C8: 100 Choice_Decision__('Kolkata',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Kolkata',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Kolkata',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Kolkata',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Kolkata',_'Chennai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Kolkata',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Kolkata',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Kolkata',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Kolkata',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Kolkata',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Kolkata',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Kolkata',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Kolkata',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Kolkata',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Kolkata',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Kolkata',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Kolkata',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Kolkata',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Kolkata',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Kolkata',_'Chennai',_'Road',_'VAN',_0) = 0
#
# _C9: 100 Choice_Decision__('Delhi',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Delhi',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Delhi',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Delhi',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Delhi',_'Mumbai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Delhi',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Delhi',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Delhi',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Delhi',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Delhi',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Delhi',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Delhi',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Delhi',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Delhi',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Delhi',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Delhi',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Delhi',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Delhi',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Delhi',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Delhi',_'Mumbai',_'Road',_'VAN',_0) >= 3000
#
# _C10: 100 Choice_Decision__('Delhi',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Delhi',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Delhi',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Delhi',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Delhi',_'Kolkata',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Delhi',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Delhi',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Delhi',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Delhi',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Delhi',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Delhi',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Delhi',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Delhi',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Delhi',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Delhi',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Delhi',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Delhi',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Delhi',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Delhi',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Delhi',_'Kolkata',_'Road',_'VAN',_0) >= 24000
#
# _C11: 100 Choice_Decision__('Delhi',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Delhi',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Delhi',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Delhi',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Delhi',_'Bangalore',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Delhi',_'Bangalore',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Delhi',_'Bangalore',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Delhi',_'Bangalore',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Delhi',_'Bangalore',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Delhi',_'Bangalore',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Delhi',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Delhi',_'Bangalore',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Delhi',_'Bangalore',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Delhi',_'Bangalore',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Delhi',_'Bangalore',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Delhi',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Delhi',_'Bangalore',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Delhi',_'Bangalore',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Delhi',_'Bangalore',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Delhi',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Delhi',_'Bangalore',_'Road',_'VAN',_0) = 0
#
# _C12: 100 Choice_Decision__('Delhi',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Delhi',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Delhi',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Delhi',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Delhi',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Delhi',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Delhi',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Delhi',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Delhi',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Delhi',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Delhi',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Delhi',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Delhi',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Delhi',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Delhi',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Delhi',_'Chennai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Delhi',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Delhi',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Delhi',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Delhi',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Delhi',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Delhi',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Delhi',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Delhi',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Delhi',_'Chennai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Delhi',_'Chennai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Delhi',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Delhi',_'Chennai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Delhi',_'Chennai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Delhi',_'Chennai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Delhi',_'Chennai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Delhi',_'Chennai',_'Road',_'VAN',_0) >= 13
#
# _C13: 100 Choice_Decision__('Bangalore',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Bangalore',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Bangalore',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Bangalore',_'Mumbai',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Bangalore',_'Mumbai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Bangalore',_'Mumbai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Bangalore',_'Mumbai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Bangalore',_'Mumbai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Bangalore',_'Mumbai',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Bangalore',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Bangalore',_'Mumbai',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Bangalore',_'Mumbai',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Bangalore',_'Mumbai',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Bangalore',_'Mumbai',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Bangalore',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Bangalore',_'Mumbai',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Bangalore',_'Mumbai',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Bangalore',_'Mumbai',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Bangalore',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Bangalore',_'Mumbai',_'Road',_'VAN',_0) >= 100
#
# _C14: 100 Choice_Decision__('Bangalore',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Bangalore',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Bangalore',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Bangalore',_'Kolkata',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Bangalore',_'Kolkata',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Bangalore',_'Kolkata',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Bangalore',_'Kolkata',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Bangalore',_'Kolkata',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Bangalore',_'Kolkata',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Bangalore',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Bangalore',_'Kolkata',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Bangalore',_'Kolkata',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Bangalore',_'Kolkata',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Bangalore',_'Kolkata',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Bangalore',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Bangalore',_'Kolkata',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Bangalore',_'Kolkata',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Bangalore',_'Kolkata',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Bangalore',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Bangalore',_'Kolkata',_'Road',_'VAN',_0) >= 13130
#
# _C15: 100 Choice_Decision__('Bangalore',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Bangalore',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Bangalore',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Bangalore',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Choice_Decision__('Bangalore',_'Delhi',_'Road',_'VAN',_0)
#  + 100 Return_Count__('Bangalore',_'Delhi',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Return_Count__('Bangalore',_'Delhi',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Return_Count__('Bangalore',_'Delhi',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Return_Count__('Bangalore',_'Delhi',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Return_Count__('Bangalore',_'Delhi',_'Road',_'4x4',_0)
#  + 2 Return_Count__('Bangalore',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Return_Count__('Bangalore',_'Delhi',_'Road',_'ELECTRIC',_0)
#  + Return_Count__('Bangalore',_'Delhi',_'Road',_'ESTATE',_0)
#  + 36 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_0)
#  + 36 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_1)
#  + 36 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_(Large)',_2)
#  + 15 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_(Small)',_0)
#  + 24 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0)
#  + 4 Return_Count__('Bangalore',_'Delhi',_'Road',_'HGV_LOADER',_0)
#  + 8 Return_Count__('Bangalore',_'Delhi',_'Road',_'LARGE_VAN',_0)
#  + 13 Return_Count__('Bangalore',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0)
#  + 9 Return_Count__('Bangalore',_'Delhi',_'Road',_'PANEL_VAN',_0)
#  + 10 Return_Count__('Bangalore',_'Delhi',_'Road',_'PICK__UP',_0)
#  + 11 Return_Count__('Bangalore',_'Delhi',_'Road',_'TIPPER',_0)
#  + 3 Return_Count__('Bangalore',_'Delhi',_'Road',_'TIPPER_(HGV)',_0)
#  + 12 Return_Count__('Bangalore',_'Delhi',_'Road',_'VAN',_0) = 0
#
# _C16: 100 Choice_Decision__('Bangalore',_'Chennai',_'Air',_'CARGO_PLANE',_0)
#  + 8000 Choice_Decision__('Bangalore',_'Chennai',_'Rail',_'GOODS_RAIL',_0)
#  + 5000 Choice_Decision__('Bangalore',_'Chennai',_'Rail',_'MIXED_RAIL',_0)
#  + 18 Choice_Decision__('Bangalore',_'Chennai',_'Road',_'4WD_PICK_UP',_0)
#  + 2 Choice_Decision__('Bangalore',_'Chennai',_'Road',_'4x4',_0)
#  + 2 Choice_Decision__('Bangalore',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0)
#  + 7 Choice_Decision__('Bangalore',_'Chennai',_'Road',_'ELECTRIC',_0)
#  + Choice_Decision__('Bangalore',_'Chennai',_'Road',_'ESTATE',_0)
#  + 36 Choice_Decision__('Bangalore',_'Chennai',_'Road',_'HGV_(Large)',_0)
# ...
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Chennai',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Kolkata',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Delhi',_'Mumbai',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Bangalore',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Chennai',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Delhi',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Kolkata',_'Mumbai',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Bangalore',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Chennai',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Delhi',_'Road',_'VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Air',_'CARGO_PLANE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Rail',_'GOODS_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Rail',_'MIXED_RAIL',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'4WD_PICK_UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'4x4',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'CAR_DERIVED_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'ELECTRIC',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'ESTATE',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_1) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Large)',_2) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_(Small)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_DROPSIDE_LORRY',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'HGV_LOADER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'LARGE_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'MOTOR_CARAVAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'PANEL_VAN',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'PICK__UP',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'TIPPER',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'TIPPER_(HGV)',_0) Integer
# 0 <= Return_Count__('Mumbai',_'Kolkata',_'Road',_'VAN',_0) Integer
# >

# %%
#######################################################################
#------------------- Mappings Necessary for Output -------------------#
#######################################################################

mt_choice = []
mt_return =[]
for v in model.variables():
    if  v.varValue != 0 :
        if v.name.split('__(')[0]=="Choice_Decision":
            mt_choice.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue,])
        else:
            mt_return.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue+1,])

mt_choice_output = pd.DataFrame(mt_choice, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Vechile Chosen'])
mt_choice_output_df = mt_choice_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_choice_output_df['S_D_M'] = mt_choice_output_df['Source'] + '_' + mt_choice_output_df['Destination'] + '_' + mt_choice_output_df['Transportation mode']


mt_return_output = pd.DataFrame(mt_return, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Number of Trips'])
mt_return_output_df = mt_return_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_return_output_df['S_D_M'] = mt_return_output_df['Source'] + '_' + mt_return_output_df['Destination'] + '_' + mt_return_output_df['Transportation mode']

# mt_return_output_df

merged_df = mt_choice_output_df.merge(mt_return_output_df, on=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'S_D_M'], how='left')

# Fill NaN values in the 'Return Count' column with 0 (if needed)
merged_df['Number of Trips'].fillna(1, inplace=True)
count_idx = merged_df.columns.get_loc('Vechile Chosen')
merged_df.insert(count_idx + 1, 'Number of Trips', merged_df.pop('Number of Trips'))


# merged_df

# %%
merged_df.sort_values(by=['Source', 'Destination'], inplace=True)

merged_df.reset_index(drop=True, inplace=True)
ans_of_iteration1=merged_df
ans_of_iteration1
# Out:
#       Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Bangalore     Kolkata                Rail   GOODS_RAIL              0
# 1    Chennai   Bangalore                Rail   GOODS_RAIL              0
# 2    Chennai     Kolkata                Rail   GOODS_RAIL              0
# 3      Delhi     Kolkata                 Air  CARGO_PLANE              0
# 4      Delhi     Kolkata                Rail   GOODS_RAIL              0
# 5      Delhi     Kolkata                Rail   MIXED_RAIL              0
# 6      Delhi     Kolkata                Road  HGV_(Large)              0
# 7      Delhi     Kolkata                Road  HGV_(Large)              1
# 8      Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Vechile Chosen  Number of Trips                   S_D_M
# 0        1.000000         1.256057  Bangalore_Kolkata_Rail
# 1        1.000000         4.157195  Chennai_Bangalore_Rail
# 2        0.720611         1.335639    Chennai_Kolkata_Rail
# 3        1.000000         7.403553       Delhi_Kolkata_Air
# 4        1.000000         1.253700      Delhi_Kolkata_Rail
# 5        1.000000         1.776661      Delhi_Kolkata_Rail
# 6        1.000000         0.969771      Delhi_Kolkata_Road
# 7        1.000000         0.969771      Delhi_Kolkata_Road
# 8        1.000000         0.969771      Delhi_Kolkata_Road

# %%
# Adding Co2 emission
co2_emission_values = []
time_value=[]
cost_value=[]
for index, row in ans_of_iteration1.iterrows():
    s = row['Source']
    d = row['Destination']
    m= row['Transportation mode']
    v = row['Vehicle type']
    v=v.replace("_"," ")
    r_t=row['Number of Trips']
    # print(v)
    
    distance_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                     (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)][m + ' Distance (km)'].item()
    
    co2_emissions_g_per_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                                (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)]['Co2e (g/km)'].item()
    
    if input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
        exp1 = distance_km/df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Avg Speed (km/hr)'].item()
        exp2=(2.5*(r_t-1)+1)*exp1
        time_value.append(exp2)

    cost_value.append(r_t*distance_km*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Cost per km'].item())
    co2_emission_values.append(2*r_t*distance_km*co2_emissions_g_per_km)

ans_of_iteration1["Total Co2 Emission"]=co2_emission_values
ans_of_iteration1['Total Co2 Emission'] = ans_of_iteration1['Total Co2 Emission'].apply(lambda x: round(x, 2))
ans_of_iteration1["Total Time"]=time_value
ans_of_iteration1["Cost To Journey"]=cost_value
# ans_of_iteration1

# %%
source_destination_table = merged_df[(merged_df['Source'] == 'Delhi') & (merged_df['Destination'] == 'Kolkata')].copy()
source_destination_table
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 3  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 4  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 5  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 6  Delhi     Kolkata                Road  HGV_(Large)              0
# 7  Delhi     Kolkata                Road  HGV_(Large)              1
# 8  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Vechile Chosen  Number of Trips               S_D_M  Total Co2 Emission  \
# 3             1.0         7.403553   Delhi_Kolkata_Air         10684062.85
# 4             1.0         1.253700  Delhi_Kolkata_Rail           333068.18
# 5             1.0         1.776661  Delhi_Kolkata_Rail           518080.29
# 6             1.0         0.969771  Delhi_Kolkata_Road           493301.65
# 7             1.0         0.969771  Delhi_Kolkata_Road           493301.65
# 8             1.0         0.969771  Delhi_Kolkata_Road           493301.65
#
#    Total Time  Cost To Journey
# 3        44.5     96848.839522
# 4        44.5      6827.551973
# 5        44.5     13303.883979
# 6        44.5      1952.273221
# 7        44.5      1952.273221
# 8        44.5      1952.273221

# %%
first_best_co2_emission = pulp.value(model.objective)
print(first_best_co2_emission)



# df
# Out:
# 104962.88044245592

# %%
# print(first_best_co2_emission+0.00001)
model += (model.objective >= first_best_co2_emission+0.00001)

# %%
# %%time
###############################################
#------------------- Solve -------------------#
###############################################

model.solve()
print(pulp.LpStatus[model.status])
# Out:
# Infeasible
# CPU times: total: 15.6 ms
# Wall time: 91 ms

# %%
second_best_co2_emission = pulp.value(model.objective)
print(second_best_co2_emission)
# Out:
# 104962.87921783663

# %%
mt_choice = []
mt_return =[]
for v in model.variables():
    if  v.varValue != 0 :
        if v.name.split('__(')[0]=="Choice_Decision":
            mt_choice.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue,])
        else:
            mt_return.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue+1,])

mt_choice_output = pd.DataFrame(mt_choice, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Vechile Chosen'])
mt_choice_output_df = mt_choice_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_choice_output_df['S_D_M'] = mt_choice_output_df['Source'] + '_' + mt_choice_output_df['Destination'] + '_' + mt_choice_output_df['Transportation mode']


mt_return_output = pd.DataFrame(mt_return, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Number of Trips'])
mt_return_output_df = mt_return_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_return_output_df['S_D_M'] = mt_return_output_df['Source'] + '_' + mt_return_output_df['Destination'] + '_' + mt_return_output_df['Transportation mode']

# mt_return_output_df

merged_df = mt_choice_output_df.merge(mt_return_output_df, on=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'S_D_M'], how='left')

# Fill NaN values in the 'Return Count' column with 0 (if needed)
merged_df['Number of Trips'].fillna(1, inplace=True)
count_idx = merged_df.columns.get_loc('Vechile Chosen')
merged_df.insert(count_idx + 1, 'Number of Trips', merged_df.pop('Number of Trips'))


merged_df
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 1  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 2  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 3  Delhi     Kolkata                Road  HGV_(Large)              0
# 4  Delhi     Kolkata                Road  HGV_(Large)              1
# 5  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Vechile Chosen  Number of Trips               S_D_M
# 0        1.000000         7.403553   Delhi_Kolkata_Air
# 1        1.000000         1.253700  Delhi_Kolkata_Rail
# 2        1.000000         1.776661  Delhi_Kolkata_Rail
# 3        1.000000         0.969771  Delhi_Kolkata_Road
# 4        0.924427         1.000000  Delhi_Kolkata_Road
# 5      527.699250      -209.709930  Delhi_Kolkata_Road

# %%
merged_df.sort_values(by=['Source', 'Destination'], inplace=True)

merged_df.reset_index(drop=True, inplace=True)
ans_of_iteration2=merged_df

# %%
# Adding Co2 emission
co2_emission_values = []
time_value=[]
cost_value=[]
for index, row in ans_of_iteration2.iterrows():
    s = row['Source']
    d = row['Destination']
    m= row['Transportation mode']
    v = row['Vehicle type']
    v=v.replace("_"," ")
    r_t=row['Number of Trips']
    # print(v)
    
    distance_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                     (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)][m + ' Distance (km)'].item()
    
    co2_emissions_g_per_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                                (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)]['Co2e (g/km)'].item()
    
    if input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
        exp1 = distance_km/df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Avg Speed (km/hr)'].item()
        exp2=(2.5*(r_t-1)+1)*exp1
        time_value.append(exp2)

    cost_value.append(r_t*distance_km*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Cost per km'].item())
    co2_emission_values.append(2*r_t*distance_km*co2_emissions_g_per_km)

ans_of_iteration2["Total Co2 Emission"]=co2_emission_values
ans_of_iteration2['Total Co2 Emission'] = ans_of_iteration2['Total Co2 Emission'].apply(lambda x: round(x, 2))
ans_of_iteration2["Total Time"]=time_value
ans_of_iteration2["Cost To Journey"]=cost_value
ans_of_iteration2
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 1  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 2  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 3  Delhi     Kolkata                Road  HGV_(Large)              0
# 4  Delhi     Kolkata                Road  HGV_(Large)              1
# 5  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Vechile Chosen  Number of Trips               S_D_M  Total Co2 Emission  \
# 0        1.000000         7.403553   Delhi_Kolkata_Air        1.068406e+07
# 1        1.000000         1.253700  Delhi_Kolkata_Rail        3.330682e+05
# 2        1.000000         1.776661  Delhi_Kolkata_Rail        5.180803e+05
# 3        1.000000         0.969771  Delhi_Kolkata_Road        4.933017e+05
# 4        0.924427         1.000000  Delhi_Kolkata_Road        5.086787e+05
# 5      527.699250      -209.709930  Delhi_Kolkata_Road       -1.066750e+08
#
#      Total Time  Cost To Journey
# 0     44.500000     96848.839522
# 1     44.500000      6827.551973
# 2     44.500000     13303.883979
# 3     44.500000      1952.273221
# 4     48.137941      2013.128700
# 5 -25309.717598   -422173.078758

# %%
source_destination_table = merged_df[(merged_df['Source'] == 'Delhi') & (merged_df['Destination'] == 'Kolkata')].copy()
source_destination_table
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 1  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 2  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 3  Delhi     Kolkata                Road  HGV_(Large)              0
# 4  Delhi     Kolkata                Road  HGV_(Large)              1
# 5  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Vechile Chosen  Number of Trips               S_D_M  Total Co2 Emission  \
# 0        1.000000         7.403553   Delhi_Kolkata_Air        1.068406e+07
# 1        1.000000         1.253700  Delhi_Kolkata_Rail        3.330682e+05
# 2        1.000000         1.776661  Delhi_Kolkata_Rail        5.180803e+05
# 3        1.000000         0.969771  Delhi_Kolkata_Road        4.933017e+05
# 4        0.924427         1.000000  Delhi_Kolkata_Road        5.086787e+05
# 5      527.699250      -209.709930  Delhi_Kolkata_Road       -1.066750e+08
#
#      Total Time  Cost To Journey
# 0     44.500000     96848.839522
# 1     44.500000      6827.551973
# 2     44.500000     13303.883979
# 3     44.500000      1952.273221
# 4     48.137941      2013.128700
# 5 -25309.717598   -422173.078758

# %%
model += (model.objective >= second_best_co2_emission+0.001)
model.solve()
print(pulp.LpStatus[model.status])
# Out:
# Infeasible

# %%
third_best_co2_emission = pulp.value(model.objective)
print(third_best_co2_emission)
# Out:
# 104962.88090475413

# %%
mt_choice = []
mt_return =[]
for v in model.variables():
    if  v.varValue != 0 :
        if v.name.split('__(')[0]=="Choice_Decision":
            mt_choice.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue,])
        else:
            mt_return.append(v.name.split('__(')[1].rstrip(')').split(',_') + [v.varValue+1,])

mt_choice_output = pd.DataFrame(mt_choice, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Vechile Chosen'])
mt_choice_output_df = mt_choice_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_choice_output_df['S_D_M'] = mt_choice_output_df['Source'] + '_' + mt_choice_output_df['Destination'] + '_' + mt_choice_output_df['Transportation mode']


mt_return_output = pd.DataFrame(mt_return, columns=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'Number of Trips'])
mt_return_output_df = mt_return_output.applymap(lambda x: x.strip("'") if isinstance(x, str) else x)
mt_return_output_df['S_D_M'] = mt_return_output_df['Source'] + '_' + mt_return_output_df['Destination'] + '_' + mt_return_output_df['Transportation mode']

# mt_return_output_df

merged_df = mt_choice_output_df.merge(mt_return_output_df, on=['Source', 'Destination', 'Transportation mode', 'Vehicle type', 'Vehicle number', 'S_D_M'], how='left')

# Fill NaN values in the 'Return Count' column with 0 (if needed)
merged_df['Number of Trips'].fillna(1, inplace=True)
count_idx = merged_df.columns.get_loc('Vechile Chosen')
merged_df.insert(count_idx + 1, 'Number of Trips', merged_df.pop('Number of Trips'))


merged_df.sort_values(by=['Source', 'Destination'], inplace=True)

merged_df.reset_index(drop=True, inplace=True)
ans_of_iteration3=merged_df



# Adding Co2 emission
co2_emission_values = []
time_value=[]
cost_value=[]
for index, row in ans_of_iteration3.iterrows():
    s = row['Source']
    d = row['Destination']
    m= row['Transportation mode']
    v = row['Vehicle type']
    v=v.replace("_"," ")
    r_t=row['Number of Trips']
    # print(v)
    
    distance_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                     (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)][m + ' Distance (km)'].item()
    
    co2_emissions_g_per_km = df[(df['Source'] == s) & (df['Destination'] == d) & 
                                (df['Transportation modes'] == m) & (df['Vehicle_type'] == v)]['Co2e (g/km)'].item()
    
    if input_df[(input_df['From']==s) & (input_df['To']==d)].shape[0]:
        exp1 = distance_km/df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Avg Speed (km/hr)'].item()
        exp2=(2.5*(r_t-1)+1)*exp1
        time_value.append(exp2)

    cost_value.append(r_t*distance_km*df[(df['Source']==s) & (df['Destination']==d) & (df['Transportation modes']==m) & (df['Vehicle_type']==v)]['Cost per km'].item())
    co2_emission_values.append(2*r_t*distance_km*co2_emissions_g_per_km)

ans_of_iteration3["Total Co2 Emission"]=co2_emission_values
ans_of_iteration3['Total Co2 Emission'] = ans_of_iteration3['Total Co2 Emission'].apply(lambda x: round(x, 2))
ans_of_iteration3["Total Time"]=time_value
ans_of_iteration3["Cost To Journey"]=cost_value
# ans_of_iteration3/

# %%
ans_of_iteration1.drop(columns=["Vechile Chosen", "S_D_M"], inplace=True)
ans_of_iteration2.drop(columns=["Vechile Chosen", "S_D_M"], inplace=True)
ans_of_iteration3.drop(columns=["Vechile Chosen", "S_D_M"], inplace=True)

# %%
# ans_of_iteration1.to_csv('../data/Output_data/v3/Ans_Iteration_1.csv', index=False)
ans_of_iteration1
# Out:
#       Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Bangalore     Kolkata                Rail   GOODS_RAIL              0
# 1    Chennai   Bangalore                Rail   GOODS_RAIL              0
# 2    Chennai     Kolkata                Rail   GOODS_RAIL              0
# 3      Delhi     Kolkata                 Air  CARGO_PLANE              0
# 4      Delhi     Kolkata                Rail   GOODS_RAIL              0
# 5      Delhi     Kolkata                Rail   MIXED_RAIL              0
# 6      Delhi     Kolkata                Road  HGV_(Large)              0
# 7      Delhi     Kolkata                Road  HGV_(Large)              1
# 8      Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Number of Trips  Total Co2 Emission  Total Time  Cost To Journey
# 0         1.256057           397500.32   53.200000      8148.343991
# 1         4.157195           246288.76   54.000000      5048.664017
# 2         1.335639           367617.73   51.881675      7535.781976
# 3         7.403553         10684062.85   44.500000     96848.839522
# 4         1.253700           333068.18   44.500000      6827.551973
# 5         1.776661           518080.29   44.500000     13303.883979
# 6         0.969771           493301.65   44.500000      1952.273221
# 7         0.969771           493301.65   44.500000      1952.273221
# 8         0.969771           493301.65   44.500000      1952.273221

# %%
ans_of_iteration2.to_csv('../data/Output_data/v3/Ans_Iteration_2.csv', index=False)
ans_of_iteration2
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 1  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 2  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 3  Delhi     Kolkata                Road  HGV_(Large)              0
# 4  Delhi     Kolkata                Road  HGV_(Large)              1
# 5  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Number of Trips  Total Co2 Emission    Total Time  Cost To Journey
# 0         7.403553        1.068406e+07     44.500000     96848.839522
# 1         1.253700        3.330682e+05     44.500000      6827.551973
# 2         1.776661        5.180803e+05     44.500000     13303.883979
# 3         0.969771        4.933017e+05     44.500000      1952.273221
# 4         1.000000        5.086787e+05     48.137941      2013.128700
# 5      -209.709930       -1.066750e+08 -25309.717598   -422173.078758

# %%
ans_of_iteration3.to_csv('../data/Output_data/v3/Ans_Iteration_3.csv', index=False)
ans_of_iteration3
# Out:
#   Source Destination Transportation mode Vehicle type Vehicle number  \
# 0  Delhi     Kolkata                 Air  CARGO_PLANE              0
# 1  Delhi     Kolkata                Rail   GOODS_RAIL              0
# 2  Delhi     Kolkata                Rail   MIXED_RAIL              0
# 3  Delhi     Kolkata                Road  HGV_(Large)              0
# 4  Delhi     Kolkata                Road  HGV_(Large)              1
# 5  Delhi     Kolkata                Road  HGV_(Large)              2
#
#    Number of Trips  Total Co2 Emission    Total Time  Cost To Journey
# 0         7.403553        1.068406e+07     44.500000     96848.839522
# 1         1.253700        3.330682e+05     44.500000      6827.551973
# 2         1.776661        5.180803e+05     44.500000     13303.883979
# 3         0.969771        4.933017e+05     44.500000      1952.273221
# 4         0.969771        4.933017e+05     44.500000      1952.273221
# 5      -209.679700       -1.066596e+08 -25306.079573   -422112.221877

# %%
grouped_df1 = ans_of_iteration1.groupby(['Source', 'Destination']).agg({
     'Vehicle type': 'count',
    'Total Co2 Emission': 'sum',
    'Total Time': 'max',
    'Cost To Journey': 'sum',
   
}).reset_index()

# Rename the columns for clarity
grouped_df1.rename(columns={'Vehicle type': 'Total Vehicles'}, inplace=True)
input_df = input_df.rename(columns={"From": "Source", "To": "Destination"})
# Display the resulting table
grouped_df1 = pd.merge(input_df, grouped_df1, on=["Source", "Destination"])
grouped_df1 = grouped_df1.rename(columns={"Quantity (MT)": "Quantity Constraint", "Time (hrs)": "Time Constraint","Cost":"Cost Constraint"})
grouped_df1
# Out:
#       Source Destination  Quantity Constraint  Time Constraint  \
# 0      Delhi     Kolkata                24000             44.5
# 1  Bangalore     Kolkata                13130             53.2
# 2    Chennai     Kolkata                 8450             44.0
# 3    Chennai   Bangalore                35618             54.0
#
#    Cost Constraint  Total Vehicles  Total Co2 Emission  Total Time  \
# 0            30450               6         13015116.27   44.500000
# 1           190320               1           397500.32   53.200000
# 2            28500               1           367617.73   51.881675
# 3           175000               1           246288.76   54.000000
#
#    Cost To Journey
# 0    122837.095137
# 1      8148.343991
# 2      7535.781976
# 3      5048.664017

# %%
grouped_df2 = ans_of_iteration2.groupby(['Source', 'Destination']).agg({
    'Vehicle type': 'count',
    'Total Co2 Emission': 'sum',
    'Total Time': 'max',
    'Cost To Journey': 'sum',
    
}).reset_index()

# Rename the columns for clarity
grouped_df2.rename(columns={'Vehicle type': 'Total Vehicles'}, inplace=True)

# Display the resulting table
grouped_df2
grouped_df2 = pd.merge(input_df, grouped_df2, on=["Source", "Destination"])
grouped_df2 = grouped_df2.rename(columns={"Quantity (MT)": "Quantity Constraint", "Time (hrs)": "Time Constraint","Cost":"Cost Constraint"})
grouped_df2
# Out:
#   Source Destination  Quantity Constraint  Time Constraint  Cost Constraint  \
# 0  Delhi     Kolkata                24000             44.5            30450
#
#    Total Vehicles  Total Co2 Emission  Total Time  Cost To Journey
# 0               6        -94137772.04   48.137941   -301227.401362

# %%
grouped_df3 = ans_of_iteration3.groupby(['Source', 'Destination']).agg({
    'Vehicle type': 'count',
    'Total Co2 Emission': 'sum',
    'Total Time': 'max',
    'Cost To Journey': 'sum',
    
}).reset_index()

# Rename the columns for clarity
grouped_df3.rename(columns={'Vehicle type': 'Total Vehicles'}, inplace=True)

# Display the resulting table

grouped_df3
grouped_df3 = pd.merge(input_df, grouped_df3, on=["Source", "Destination"])
grouped_df3 = grouped_df3.rename(columns={"Quantity (MT)": "Quantity Constraint", "Time (hrs)": "Time Constraint","Cost":"Cost Constraint"})
grouped_df3
# Out:
#   Source Destination  Quantity Constraint  Time Constraint  Cost Constraint  \
# 0  Delhi     Kolkata                24000             44.5            30450
#
#    Total Vehicles  Total Co2 Emission  Total Time  Cost To Journey
# 0               6        -94137771.69        44.5   -301227.399961

# %%
ans_of_iteration1.to_csv("../data/Output_data/v3/Ans_Iteration_1.csv", index=False)
with open("../data/Output_data/v3/Ans_Iteration_1.csv", "a") as f:
    f.write("\n\n\n")
# Write table2_df to CSV and append it to the existing file
grouped_df1.to_csv("../data/Output_data/v3/Ans_Iteration_1.csv", index=False, mode='a', header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 ans_of_iteration1.to_csv("../data/Output_data/v3/Ans_Iteration_1.csv", index=False)
#       2 with open("../data/Output_data/v3/Ans_Iteration_1.csv", "a") as f:
#       3     f.write("\n\n\n")
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Python311\Lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Python311\Lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '../data/Output_data/v3/Ans_Iteration_1.csv'

# %%
ans_of_iteration2.to_csv("../data/Output_data/v3/Ans_Iteration_2.csv", index=False)
with open("../data/Output_data/v3/Ans_Iteration_2.csv", "a") as f:
    f.write("\n\n\n")
# Write table2_df to CSV and append it to the existing file
grouped_df2.to_csv("../data/Output_data/v3/Ans_Iteration_2.csv", index=False, mode='a', header=True)

# %%
ans_of_iteration3.to_csv("../data/Output_data/v3/Ans_Iteration_3.csv", index=False)
with open("../data/Output_data/v3/Ans_Iteration_3.csv", "a") as f:
    f.write("\n\n\n")
# Write table2_df to CSV and append it to the existing file
grouped_df3.to_csv("../data/Output_data/v3/Ans_Iteration_3.csv", index=False, mode='a', header=True)

# %%
grouped_df1.to_csv("../data/Output_data/v3/Compare_Iterations.csv", index=False)
with open("../data/Output_data/v3/Compare_Iterations.csv", "a") as f:
    f.write("\n\n\n")
# Write table2_df to CSV and append it to the existing file
grouped_df2.to_csv("../data/Output_data/v3/Compare_Iterations.csv", index=False, mode='a', header=True)
with open("../data/Output_data/v3/Compare_Iterations.csv", "a") as f:
    f.write("\n\n\n")
grouped_df3.to_csv("../data/Output_data/v3/Compare_Iterations.csv", index=False, mode='a', header=True)
